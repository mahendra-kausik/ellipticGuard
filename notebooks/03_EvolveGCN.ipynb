# %% [markdown]
# # Phase 3 — EvolveGCN-H Training
# **Project:** Temporal GNN + XAI for Anti-Money Laundering
# **Model:** EvolveGCN-H (GRU-evolved weight matrices across 49 snapshots)
# **Purpose:** Show drift resilience vs Static GCN baseline from Phase 2.
#
# ### Key Differences from Static GCN
# | Aspect | Static GCN | EvolveGCN-H |
# |--------|-----------|-------------|
# | Weights after training | Frozen | Evolve via GRU each snapshot |
# | Snapshot order matters | No | **Yes — must be chronological** |
# | Temporal memory | None | GRU hidden state = evolved weights |
# | Gradient clipping | Not needed | **Required** |
# | Epochs to converge | ~76 | ~100–150 |
#
# ### Temporal Split (same as Phase 2)
# | Split | Snapshots | Indices (0-based) |
# |-------|-----------|-------------------|
# | Train | T1 – T34  | 0 – 33            |
# | Val   | T35 – T36 | 34 – 35           |
# | Test  | T37 – T49 | 36 – 48           |
#
# ### Cells in this notebook
# 1. Install dependencies
# 2. Imports & global config
# 3. Device setup
# 4. Load snapshots
# 5. Verify splits
# 6. EvolveGCN-H model definition
# 7. Loss function & optimizer
# 8. Training & evaluation functions
# 9. Main training loop with early stopping
# 10. Training curve plot
# 11. Load best model & full test evaluation
# 12. Per-snapshot F1 & AUROC (comparison with Static GCN)
# 13. Drift visualisation — both models on same plot
# 14. Drift probe
# 15. Save all outputs for Phase 4 SHAP

# %% [markdown]
# ---
# ## Cell 1 — Install Dependencies

# %%
# ── Dependencies (Google Colab) ───────────────────────────────────────────────
# torch is pre-installed on Colab. Modern torch-geometric (>=2.4) does NOT need
# torch-scatter / torch-sparse for anything used in this project (GCNConv,
# scatter_add, add_self_loops, degree, to_undirected) — it falls back to native
# torch, so this install is fast and robust across torch versions.
import torch
print(f'PyTorch : {torch.__version__}   |   CUDA available : {torch.cuda.is_available()}')

# !pip install -q torch-geometric
# !pip install -q shap scikit-learn matplotlib seaborn numpy

# Optional — only if some op ever demands the compiled kernels (normally NOT needed):
# v  = torch.__version__.split('+')[0]
# cu = ('cu' + torch.version.cuda.replace('.', '')) if torch.cuda.is_available() else 'cpu'
# !pip install -q torch-scatter torch-sparse -f https://data.pyg.org/whl/torch-{v}+{cu}.html

print('Dependencies installed.')

# %% [markdown]
# ---
# ## Cell 2 — Imports & Global Config

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import json
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from sklearn.metrics import f1_score, roc_auc_score, precision_score, recall_score
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams.update({'figure.dpi': 120, 'font.size': 11})

# ── Reproducibility ───────────────────────────────────────────────────────────
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)

# ── Paths (unified — same BASE_DIR as notebooks 01/02/04) ─────────────────────
BASE_DIR      = '/content/drive/MyDrive/Capstone/Testing'
PROCESSED_DIR = os.path.join(BASE_DIR, 'data', 'processed')
MODELS_DIR    = os.path.join(BASE_DIR, 'models')
FIGURES_DIR   = os.path.join(BASE_DIR, 'figures')

for d in [MODELS_DIR, FIGURES_DIR]:
    os.makedirs(d, exist_ok=True)

# ── Temporal split (0-based indices) ──────────────────────────────────────────
TRAIN_IDX = list(range(0,  34))   # T1  – T34
VAL_IDX   = list(range(34, 36))   # T35 – T36
TEST_IDX  = list(range(36, 49))   # T37 – T49
ALL_IDX   = list(range(0,  49))   # T1  – T49 (warm-up for temporal eval)

# ── Hyper-parameters — SINGLE SOURCE OF TRUTH (wired through everywhere) ───────
IN_CHANNELS     = 165
HIDDEN1         = 64
HIDDEN2         = 32
DROPOUT         = 0.5
LR              = 0.001         # used by every optimizer below
WEIGHT_DECAY    = 1e-4
MAX_EPOCHS      = 500           # EvolveGCN converges slower than Static GCN
PATIENCE        = 40
CLASS_W_ILLICIT = 5.0          # HARD INVARIANT: 5.0 not 9.0 (9.0 → all-illicit collapse)
GRAD_CLIP       = 1.0          # gradient clipping — mandatory for GRU stability
USE_SCHEDULER   = True         # ReduceLROnPlateau(factor=0.5, patience=10) on val AUROC

# ── Drift probe ───────────────────────────────────────────────────────────────
DRIFT_TRAIN_IDX = list(range(0,  16))   # T1  – T16
DRIFT_TEST_IDX  = list(range(32, 49))   # T33 – T49

SHUTDOWN_STEP   = 43

print('Config loaded (single source of truth).')
print(f'Train : T1–T34   ({len(TRAIN_IDX)} snapshots)')
print(f'Val   : T35–T36  ({len(VAL_IDX)} snapshots)')
print(f'Test  : T37–T49  ({len(TEST_IDX)} snapshots)')
print(f'lr={LR}  class_weight=[1.0, {CLASS_W_ILLICIT}]  grad_clip={GRAD_CLIP}  '
      f'scheduler={USE_SCHEDULER}')
print(f'Max epochs : {MAX_EPOCHS}  |  Patience : {PATIENCE}')
# Out:
# Config loaded (single source of truth).
# Train : T1–T34   (34 snapshots)
# Val   : T35–T36  (2 snapshots)
# Test  : T37–T49  (13 snapshots)
# lr=0.001  class_weight=[1.0, 5.0]  grad_clip=1.0  scheduler=True
# Max epochs : 500  |  Patience : 40

# %% [markdown]
# ---
# ## Cell 3 — Device Setup

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
    torch.cuda.manual_seed(SEED)
elif torch.backends.mps.is_available():
    device = torch.device('mps')
else:
    device = torch.device('cpu')

print(f'Device : {device}')
if device.type == 'cuda':
    print(f'GPU    : {torch.cuda.get_device_name(0)}')
# Out:
# Device : cpu

# %% [markdown]
# ---
# ## Cell 4 — Load Snapshots

# %%
snapshots_path = os.path.join(PROCESSED_DIR, 'snapshots.pt')
snapshots = torch.load(snapshots_path, weights_only=False)

print(f'Snapshots loaded  : {len(snapshots)}')
print(f'Feature dimension : {snapshots[0].x.shape[1]}  (expected: 165)')
print(f'Unique labels     : {torch.unique(snapshots[0].y).tolist()}  (expected: [0, 1])')

for s in snapshots:
    assert s.x.shape[1] == IN_CHANNELS, f'T{s.time_step.item()} wrong feature dim'
    assert not torch.isnan(s.x).any(), f'T{s.time_step.item()} has NaN'

print('All 49 snapshots passed sanity checks.')
# Out:
# Snapshots loaded  : 49
# Feature dimension : 165  (expected: 165)
# Unique labels     : [-1, 0, 1]  (expected: [0, 1])
# All 49 snapshots passed sanity checks.

# %% [markdown]
# ---
# ## Cell 5 — Verify Splits

# %%
print('SPLIT VERIFICATION  (Weber graph — unknown nodes present, masked)')
print('=' * 60)
for split_name, idx_list in [('TRAIN', TRAIN_IDX), ('VAL', VAL_IDX), ('TEST', TEST_IDX)]:
    snaps          = [snapshots[i] for i in idx_list]
    t_steps        = [s.time_step.item() for s in snaps]
    total_nodes    = sum(s.num_nodes for s in snaps)
    total_labelled = sum(int(s.label_mask.sum().item()) for s in snaps)
    total_illicit  = sum(int((s.y == 1).sum().item())   for s in snaps)
    pct = total_illicit / total_labelled * 100 if total_labelled else 0.0
    print(f'{split_name:6} | T{t_steps[0]}–T{t_steps[-1]}'
          f' | {len(idx_list)} snaps'
          f' | {total_nodes:,} nodes ({total_labelled:,} labelled)'
          f' | {total_illicit:,} illicit ({pct:.1f}%)')

assert not set(TRAIN_IDX) & set(VAL_IDX),  'TRAIN/VAL overlap'
assert not set(TRAIN_IDX) & set(TEST_IDX), 'TRAIN/TEST overlap'
assert not set(VAL_IDX)   & set(TEST_IDX), 'VAL/TEST overlap'
print('\nNo split overlap. Ready to train.')
# Out:
# SPLIT VERIFICATION  (Weber graph — unknown nodes present, masked)
# ...
# TRAIN  | T1–T34 | 34 snaps | 136,265 nodes (29,894 labelled) | 3,462 illicit (11.6%)
# VAL    | T35–T36 | 2 snaps | 11,900 nodes (3,049 labelled) | 215 illicit (7.1%)
# TEST   | T37–T49 | 13 snaps | 55,604 nodes (13,621 labelled) | 868 illicit (6.4%)
#
# No split overlap. Ready to train.

# %% [markdown]
# ---
# ## Cell 6 — EvolveGCN-H Model Definition
#
# ### Architecture
# ```
# Input (165 features)
#     ↓
# GRU-1 evolves W₁ (weight matrix of layer 1)
#     ↓
# EvolveGCN Layer 1: GCNConv with evolved W₁  →  ReLU
#     ↓
# GRU-2 evolves W₂ (weight matrix of layer 2)
#     ↓
# EvolveGCN Layer 2: GCNConv with evolved W₂  →  ReLU
#     ↓
# Linear classifier (32 → 2)
# ```
#
# **Why EvolveGCN-H and not -O:**
# The -O variant uses node embeddings to drive weight evolution — requires the same nodes at every snapshot.
# Elliptic has different nodes each snapshot, so -O would fail.
# The -H variant uses the weight matrix itself as the GRU hidden state — works regardless of node sets.

# %%
from torch_geometric.utils import add_self_loops, degree

class EvolveGCNLayer(nn.Module):
    """
    EvolveGCN-H layer.

    W_state is the EVOLVING weight matrix, held as a plain tensor across snapshots
    within an epoch (detached between snapshots — truncated BPTT, window = 1).
    The GRU cell weights are learnable parameters.

    E5 — the INITIAL seed W0 is a learnable nn.Parameter (canonical EvolveGCN).
    At reset_state() we clone W0 into W_state; because we do NOT detach on the very
    first snapshot, gradients reach W0 through snapshot-0 only. This makes the
    starting point trainable AND deterministic across runs (saved in state_dict),
    fixing the old bug where test re-drew a random Xavier W_state every run.

    NOT the banned bug: the banned bug is reassigning the *evolved* weights as an
    nn.Parameter inside forward(). Here the evolved W_state is always a plain tensor;
    only the fixed starting point W0 is a Parameter.
    """
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.in_channels  = in_channels
        self.out_channels = out_channels

        # GRUCell evolves the weight matrix; hidden/input size = in_channels (row width)
        self.gru = nn.GRUCell(input_size=in_channels, hidden_size=in_channels)

        # Learnable initial seed (deterministic starting point for the evolution)
        self.W0 = nn.Parameter(torch.empty(out_channels, in_channels))
        nn.init.xavier_uniform_(self.W0)

        # Evolving state — NOT a Parameter; set in reset_state()
        self.W_state = None

    def reset_state(self, device=None):
        """Start each epoch / eval pass from the learnable seed W0 (attached)."""
        self.W_state = self.W0.clone()          # attached → grad flows to W0 on snapshot-0

    def forward(self, x, edge_index):
        if self.W_state is None:
            self.reset_state()
        if self.W_state.device != x.device:
            self.W_state = self.W_state.to(x.device)

        # ── Step 1: evolve the weight matrix with the GRU cell ────────────────
        W_in = self.W_state                     # attached on snapshot-0, detached after
        z    = x.mean(dim=0)                     # (in_channels,) — full-graph feature summary
        z    = z.unsqueeze(0).repeat(self.out_channels, 1)
        W_evolved = self.gru(z, W_in)           # (out_channels, in_channels)

        # Store evolved W for next snapshot — DETACHED (truncated BPTT, window=1)
        self.W_state = W_evolved.detach()

        # ── Step 2: manual GCN convolution with the evolved weights ───────────
        edge_index_sl, _ = add_self_loops(edge_index, num_nodes=x.size(0))
        row, col = edge_index_sl

        deg          = degree(col, x.size(0), dtype=x.dtype)
        deg_inv_sqrt = deg.pow(-0.5)
        deg_inv_sqrt[deg_inv_sqrt == float('inf')] = 0
        norm = deg_inv_sqrt[row] * deg_inv_sqrt[col]

        agg = torch.zeros(x.size(0), x.size(1), device=x.device, dtype=x.dtype)
        agg.scatter_add_(
            0,
            col.unsqueeze(1).expand(-1, x.size(1)),
            norm.unsqueeze(1) * x[row]
        )
        return F.linear(agg, W_evolved)         # agg @ W_evolved^T


class EvolveGCNH(nn.Module):
    """Full EvolveGCN-H — same depth as Static GCN (165→64→32→2) for fair comparison."""
    def __init__(self, in_channels=IN_CHANNELS, hidden1=HIDDEN1, hidden2=HIDDEN2):
        super().__init__()
        self.layer1     = EvolveGCNLayer(in_channels, hidden1)
        self.layer2     = EvolveGCNLayer(hidden1,     hidden2)
        self.classifier = nn.Linear(hidden2, 2)

    def forward(self, x, edge_index):
        x = self.layer1(x, edge_index)
        x = F.relu(x)
        x = F.dropout(x, p=DROPOUT, training=self.training)
        x = self.layer2(x, edge_index)
        x = F.relu(x)
        embeddings = x
        logits     = self.classifier(x)
        return logits, embeddings

    def reset_state(self, device=None):
        """Reset both layers to their learnable seeds — call at start of every pass."""
        self.layer1.reset_state(device)
        self.layer2.reset_state(device)

    def reset_weights(self):
        """Full re-init (GRU + seeds W0 + classifier) — before a fresh training run."""
        for layer in [self.layer1, self.layer2]:
            for name, param in layer.gru.named_parameters():
                if 'weight' in name:
                    nn.init.xavier_uniform_(param)
                elif 'bias' in name:
                    nn.init.zeros_(param)
            nn.init.xavier_uniform_(layer.W0)
        nn.init.xavier_uniform_(self.classifier.weight)
        nn.init.zeros_(self.classifier.bias)

    def get_state(self):
        """Snapshot current W_state of both layers (detached) — for val continuation."""
        return (
            self.layer1.W_state.detach().clone() if self.layer1.W_state is not None else None,
            self.layer2.W_state.detach().clone() if self.layer2.W_state is not None else None,
        )

    def set_state(self, state):
        """Restore a previously saved W_state — for val/test after training."""
        dev = next(self.parameters()).device
        self.layer1.W_state = state[0].to(dev) if state[0] is not None else None
        self.layer2.W_state = state[1].to(dev) if state[1] is not None else None


model    = EvolveGCNH().to(device)
n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print('EvolveGCN-H architecture:')
print(f'  EvolveGCNLayer 1 : {IN_CHANNELS} → {HIDDEN1}  (manual GCN + GRUCell + learnable W0)')
print(f'  EvolveGCNLayer 2 : {HIDDEN1} → {HIDDEN2}  (manual GCN + GRUCell + learnable W0)')
print(f'  Linear classifier: {HIDDEN2} → 2')
print(f'  Total trainable parameters: {n_params:,}')
print()
print('W_state (evolved) is a plain tensor. W0 (seed) is a learnable Parameter.')
# Out:
# EvolveGCN-H architecture:
#   EvolveGCNLayer 1 : 165 → 64  (manual GCN + GRUCell + learnable W0)
#   EvolveGCNLayer 2 : 64 → 32  (manual GCN + GRUCell + learnable W0)
#   Linear classifier: 32 → 2
#   Total trainable parameters: 201,974
#
# W_state (evolved) is a plain tensor. W0 (seed) is a learnable Parameter.

# %% [markdown]
# ---
# ## Cell 7 — Loss Function & Optimizer

# %%
class_weights = torch.tensor([1.0, CLASS_W_ILLICIT]).to(device)
criterion     = nn.CrossEntropyLoss(weight=class_weights)   # no label_smoothing

optimizer = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)

scheduler = None
if USE_SCHEDULER:
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='max', factor=0.5, patience=10
    )

print(f'Loss      : CrossEntropyLoss  weights=[1.0, {CLASS_W_ILLICIT}]')
print(f'Optimizer : AdamW  lr={LR}  weight_decay={WEIGHT_DECAY}')
print(f'Scheduler : {"ReduceLROnPlateau(factor=0.5, patience=10)" if USE_SCHEDULER else "none"}')
# Out:
# Loss      : CrossEntropyLoss  weights=[1.0, 5.0]
# Optimizer : AdamW  lr=0.001  weight_decay=0.0001
# Scheduler : ReduceLROnPlateau(factor=0.5, patience=10)

# %% [markdown]
# ---
# ## Cell 8 — Training & Evaluation Functions
#
# **Key difference from Static GCN:**
# Snapshots must be iterated in chronological order (T1→T34) so the GRU
# accumulates temporal context correctly. Never shuffle.

# %%
# Weber graph: message passing + weight evolution use the FULL graph (incl. unknown
# nodes), but loss / metrics are computed ONLY on labelled nodes via label_mask.

def train_epoch(mdl, optim, idx_list):
    """One epoch. Resets W_state to the learnable seed, evolves T1→T34 in order."""
    mdl.train()
    mdl.reset_state(device)

    total_loss, n_used = 0.0, 0
    for i in idx_list:                       # MUST be chronological order
        data = snapshots[i].to(device)
        m    = data.label_mask
        optim.zero_grad()
        out, _ = mdl(data.x, data.edge_index)  # always forward → evolve W_state
        if m.sum() == 0:                       # no supervision this snapshot: still evolved
            continue
        loss = criterion(out[m], data.y[m])
        loss.backward()
        torch.nn.utils.clip_grad_norm_(mdl.parameters(), max_norm=GRAD_CLIP)
        optim.step()
        total_loss += loss.item()
        n_used     += 1

    end_state = mdl.get_state()               # evolved weights after last snapshot
    return total_loss / max(n_used, 1), end_state


def _metrics(y_true, y_pred, y_prob):
    auroc = roc_auc_score(y_true, y_prob) if len(set(y_true)) > 1 else float('nan')
    return {
        'F1'       : f1_score(y_true, y_pred, pos_label=1, zero_division=0),
        'AUROC'    : auroc,
        'Precision': precision_score(y_true, y_pred, pos_label=1, zero_division=0),
        'Recall'   : recall_score(y_true, y_pred, pos_label=1, zero_division=0),
    }


def evaluate_val(mdl, val_idx_list, end_state):
    """Validate by CONTINUING evolution from the end of training (T35, T36)."""
    mdl.eval()
    mdl.set_state(end_state)
    y_true, y_pred, y_prob = [], [], []
    with torch.no_grad():
        for i in val_idx_list:
            data  = snapshots[i].to(device)
            m     = data.label_mask
            out, _ = mdl(data.x, data.edge_index)
            if m.sum() == 0:
                continue
            probs = torch.softmax(out, dim=1)[:, 1]
            preds = out.argmax(dim=1)
            y_true.extend(data.y[m].cpu().numpy())
            y_pred.extend(preds[m].cpu().numpy())
            y_prob.extend(probs[m].cpu().numpy())
    return _metrics(y_true, y_pred, y_prob)


def evaluate_test(mdl, all_idx, eval_idx):
    """Warm up through all_idx from T1, report metrics on labelled eval nodes only."""
    mdl.eval()
    mdl.reset_state(device)
    y_true, y_pred, y_prob = [], [], []
    eval_set = set(eval_idx)
    with torch.no_grad():
        for i in all_idx:
            data  = snapshots[i].to(device)
            out, _ = mdl(data.x, data.edge_index)     # evolve through every snapshot
            if i in eval_set:
                m = data.label_mask
                if m.sum() == 0:
                    continue
                probs = torch.softmax(out, dim=1)[:, 1]
                preds = out.argmax(dim=1)
                y_true.extend(data.y[m].cpu().numpy())
                y_pred.extend(preds[m].cpu().numpy())
                y_prob.extend(probs[m].cpu().numpy())
    return _metrics(y_true, y_pred, y_prob)


def evaluate_per_snapshot(mdl, all_idx, eval_idx):
    """Per-snapshot metrics — warm up through all_idx, report at each labelled eval_idx."""
    mdl.eval()
    mdl.reset_state(device)
    results, eval_set = [], set(eval_idx)
    with torch.no_grad():
        for i in all_idx:
            data  = snapshots[i].to(device)
            out, _ = mdl(data.x, data.edge_index)
            if i in eval_set:
                m = data.label_mask
                if m.sum() == 0:
                    continue
                probs = torch.softmax(out, dim=1)[:, 1]
                preds = out.argmax(dim=1)
                met   = _metrics(data.y[m].cpu().numpy(),
                                 preds[m].cpu().numpy(),
                                 probs[m].cpu().numpy())
                results.append({'time_step': snapshots[i].time_step.item(), **met})
    return results


print('Functions defined (label-masked; evolve_test warms T1→T49, reports T37–T49).')
# Out:
# Functions defined (label-masked; evolve_test warms T1→T49, reports T37–T49).

# %% [markdown]
# ---
# ## Cell 9 — Main Training Loop with Early Stopping

# %%
torch.manual_seed(SEED)
model = EvolveGCNH().to(device)
model.reset_weights()
optimizer = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
if USE_SCHEDULER:
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='max', factor=0.5, patience=10
    )

best_val_auroc     = 0.0
patience_counter   = 0
best_end_state     = None
train_loss_history = []
val_auroc_history  = []
val_f1_history     = []

print(f'Training EvolveGCN-H for up to {MAX_EPOCHS} epochs (patience={PATIENCE})')
print('-' * 68)
print(f'{"Epoch":>6}  {"Train Loss":>11}  {"Val F1":>8}  {"Val AUROC":>10}  Status')
print('-' * 68)

for epoch in range(MAX_EPOCHS):
    loss, end_state = train_epoch(model, optimizer, TRAIN_IDX)
    val_met         = evaluate_val(model, VAL_IDX, end_state)
    val_f1, val_auroc = val_met['F1'], val_met['AUROC']

    train_loss_history.append(loss)
    val_auroc_history.append(val_auroc)
    val_f1_history.append(val_f1)

    if USE_SCHEDULER and not np.isnan(val_auroc):
        scheduler.step(val_auroc)

    if not np.isnan(val_auroc) and val_auroc > best_val_auroc:
        best_val_auroc   = val_auroc
        best_end_state   = end_state
        patience_counter = 0
        torch.save(model.state_dict(), os.path.join(MODELS_DIR, 'evolvegcn_best.pt'))
        status = '✓ saved'
    else:
        patience_counter += 1
        status = f'patience {patience_counter}/{PATIENCE}'

    if epoch % 10 == 0 or patience_counter == PATIENCE:
        print(f'{epoch:>6}  {loss:>11.4f}  {val_f1:>8.4f}  {val_auroc:>10.4f}  {status}')

    if patience_counter >= PATIENCE:
        print(f'\nEarly stopping at epoch {epoch}.')
        break

print(f'\nBest Val AUROC : {best_val_auroc:.4f}')
print(f'Model saved    : models/evolvegcn_best.pt')
# Out:
# Training EvolveGCN-H for up to 500 epochs (patience=40)
# --------------------------------------------------------------------
#  Epoch   Train Loss    Val F1   Val AUROC  Status
# --------------------------------------------------------------------
#      0       0.7547    0.0000      0.5000  ✓ saved
#     10       0.6711    0.0000      0.5000  patience 10/40
#     20       0.5200    0.0000      0.7704  ✓ saved
#     30       0.3974    0.0000      0.7964  patience 6/40
#     40       0.3663    0.3990      0.8724  patience 1/40
#     50       0.3115    0.4015      0.8794  patience 11/40
#     60       0.2910    0.4045      0.8770  patience 9/40
#     70       0.2686    0.4031      0.8666  patience 19/40
#     80       0.2572    0.3897      0.8603  patience 29/40
#     90       0.2517    0.3896      0.8626  patience 39/40
#     91       0.2511    0.3871      0.8625  patience 40/40
#
# Early stopping at epoch 91.
#
# Best Val AUROC : 0.8869
# Model saved    : models/evolvegcn_best.pt

# %% [markdown]
# ---
# ## Cell 10 — Training Curve Plot

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 4))
epochs_ran = range(len(train_loss_history))

axes[0].plot(epochs_ran, train_loss_history, color='#E05252', linewidth=2)
axes[0].set_title('Training Loss', fontweight='bold')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].grid(alpha=0.3)

axes[1].plot(epochs_ran, val_auroc_history, color='#0D9488', linewidth=2, label='Val AUROC')
axes[1].plot(epochs_ran, val_f1_history,    color='#F59E0B', linewidth=2, label='Val F1 (illicit)')
axes[1].axhline(best_val_auroc, color='#0D9488', linestyle=':', alpha=0.5,
                label=f'Best AUROC = {best_val_auroc:.4f}')
axes[1].set_title('Validation Metrics', fontweight='bold')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Score')
axes[1].legend()
axes[1].grid(alpha=0.3)

plt.suptitle('EvolveGCN-H — Training Curves', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig(os.path.join(FIGURES_DIR, 'evolvegcn_training_curves.png'), bbox_inches='tight')
plt.show()
print('Saved → figures/evolvegcn_training_curves.png')
# Out:
# Saved → figures/evolvegcn_training_curves.png

# %% [markdown]
# ---
# ## Cell 11 — Load Best Model & Full Test Evaluation

# %%
model.load_state_dict(
    torch.load(os.path.join(MODELS_DIR, 'evolvegcn_best.pt'),
               map_location=device, weights_only=True)
)
print('Best EvolveGCN-H model loaded.')

evolve_metrics = evaluate_test(model, ALL_IDX, TEST_IDX)

# Load static for comparison
with open(os.path.join(PROCESSED_DIR, 'static_gcn_summary.json')) as f:
    static_summary = json.load(f)
static_metrics = static_summary['test_metrics']

print()
print('COMPARISON — FULL TEST RESULTS  (T37 – T49)')
print('=' * 52)
print(f'{"Metric":<12}  {"Static GCN":>12}  {"EvolveGCN-H":>13}  Δ')
print('-' * 52)
for k in ['F1', 'AUROC', 'Precision', 'Recall']:
    s_val = static_metrics.get(k, 0)
    e_val = evolve_metrics[k]
    delta = e_val - s_val
    sign  = '+' if delta >= 0 else ''
    print(f'{k:<12}  {s_val:>12.4f}  {e_val:>13.4f}  {sign}{delta:.4f}')
print('=' * 52)
# Out:
# Best EvolveGCN-H model loaded.
#
# COMPARISON — FULL TEST RESULTS  (T37 – T49)
# ...
# Metric          Static GCN    EvolveGCN-H  Δ
# ----------------------------------------------------
# F1                  0.6285         0.1986  -0.4299
# AUROC               0.8861         0.7939  -0.0922
# Precision           0.7108         0.2449  -0.4659
# Recall              0.5634         0.1671  -0.3963
# ...

# %% [markdown]
# ---
# ## Cell 12 — Per-Snapshot Results: Pre vs Post T43

# %%
evolve_per_snap = evaluate_per_snapshot(model, ALL_IDX, TEST_IDX)

static_per_snap = static_summary['per_snapshot']
static_map      = {r['time_step']: r for r in static_per_snap}

print('PER-SNAPSHOT F1 — Static GCN vs EvolveGCN-H')
print(f'{"T":>4}  {"Static F1":>10}  {"EvolveGCN F1":>13}  {"Δ":>8}  Note')
print('-' * 60)
for r in evolve_per_snap:
    t     = r['time_step']
    e_f1  = r['F1']
    s_f1  = static_map.get(t, {}).get('F1', 0.0)
    delta = e_f1 - s_f1
    sign  = '+' if delta >= 0 else ''
    note  = '← SHUTDOWN' if t == SHUTDOWN_STEP else ''
    print(f'T{t:>2}  {s_f1:>10.4f}  {e_f1:>13.4f}  {sign}{delta:>7.4f}  {note}')

# Pre vs Post T43 — EvolveGCN computed here; Static loaded from S2 TRUE fields
e_pre  = [r['F1'] for r in evolve_per_snap if 37 <= r['time_step'] < SHUTDOWN_STEP]  # T37–T42
e_post = [r['F1'] for r in evolve_per_snap if r['time_step'] > SHUTDOWN_STEP]         # T44–T49
s_pre  = float(static_summary['pre_t43_mean_f1'])   # true Static main-test pre-T43
s_post = float(static_summary['post_t43_mean_f1'])  # true Static main-test post-T43

e_pre_m, e_post_m = float(np.mean(e_pre)), float(np.mean(e_post))

print()
print('PRE vs POST T43 SUMMARY  (both from true per-snapshot means)')
print(f'{"":20}  {"Static GCN":>12}  {"EvolveGCN-H":>13}')
print(f'{"Mean F1 pre-T43":20}  {s_pre:>12.4f}  {e_pre_m:>13.4f}')
print(f'{"Mean F1 post-T43":20}  {s_post:>12.4f}  {e_post_m:>13.4f}')
print(f'{"Drop":20}  {s_pre - s_post:>12.4f}  {e_pre_m - e_post_m:>13.4f}')
print()
print(f'F1-drop reduction vs Static : '
      f'{(1 - (e_pre_m - e_post_m) / (s_pre - s_post)) * 100:.1f}%'
      if (s_pre - s_post) > 0 else 'n/a')
# Out:
# PER-SNAPSHOT F1 — Static GCN vs EvolveGCN-H
#    T   Static F1   EvolveGCN F1         Δ  Note
# ------------------------------------------------------------
# T37      0.6000         0.3273  -0.2727
# T38      0.7845         0.4664  -0.3181
# T39      0.7471         0.0204  -0.7267
# T40      0.6702         0.0167  -0.6535
# T41      0.6881         0.2400  -0.4481
# T42      0.7678         0.1181  -0.6498
# T43      0.0000         0.0299  + 0.0299  ← SHUTDOWN
# T44      0.0556         0.0000  -0.0556
# T45      0.0000         0.0000  + 0.0000
# T46      0.0000         0.0000  + 0.0000
# T47      0.0000         0.0000  + 0.0000
# T48      0.1026         0.0909  -0.0117
# T49      0.0000         0.0000  + 0.0000
#
# PRE vs POST T43 SUMMARY  (both from true per-snapshot means)
#                         Static GCN    EvolveGCN-H
# Mean F1 pre-T43             0.7096         0.1981
# Mean F1 post-T43            0.0264         0.0152
# Drop                        0.6832         0.1830
#
# ...

# %% [markdown]
# ---
# ## Cell 13 — Drift Visualisation: Both Models on Same Plot

# %%
t_steps   = [r['time_step'] for r in evolve_per_snap]
e_f1s     = [r['F1']        for r in evolve_per_snap]
e_aurocs  = [r['AUROC']     for r in evolve_per_snap]
s_f1s     = [static_map.get(t, {}).get('F1', 0)    for t in t_steps]
s_aurocs  = [static_map.get(t, {}).get('AUROC', 0) for t in t_steps]

fig, axes = plt.subplots(1, 2, figsize=(16, 5))

for ax, s_vals, e_vals, ylabel, title in [
    (axes[0], s_f1s,    e_f1s,    'F1 Score (Illicit)',  'F1 Score Over Test Period'),
    (axes[1], s_aurocs, e_aurocs, 'AUROC',               'AUROC Over Test Period'),
]:
    ax.plot(t_steps, s_vals, marker='o', linewidth=2, markersize=6,
            color='#94A3B8', linestyle='--', label='Static GCN (baseline)')
    ax.plot(t_steps, e_vals, marker='s', linewidth=2.5, markersize=7,
            color='#0D9488', label='EvolveGCN-H (ours)')
    ax.axvline(x=SHUTDOWN_STEP, color='#E05252', linestyle='--',
               linewidth=2, label=f'T{SHUTDOWN_STEP} Dark Market Shutdown')
    ax.axvspan(37, SHUTDOWN_STEP, alpha=0.04, color='blue')
    ax.axvspan(SHUTDOWN_STEP, 49, alpha=0.06, color='red')
    ax.set_title(title, fontweight='bold')
    ax.set_xlabel('Time Snapshot')
    ax.set_ylabel(ylabel)
    ax.legend(fontsize=9)
    ax.grid(alpha=0.3)
    ax.set_xticks(t_steps)

plt.suptitle('Static GCN vs EvolveGCN-H — Concept Drift at T43',
             fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig(os.path.join(FIGURES_DIR, 'both_models_drift_comparison.png'), bbox_inches='tight')
plt.show()
print('Saved → figures/both_models_drift_comparison.png')
# Out:
# Saved → figures/both_models_drift_comparison.png

# %% [markdown]
# ---
# ## Cell 14 — Pre/Post T43 Bar Chart

# %%
# Static values loaded from Phase 2 summary (no hardcoding)
s_pre_f1  = float(static_summary['pre_t43_mean_f1'])
s_post_f1 = float(static_summary['post_t43_mean_f1'])
e_pre_f1  = float(np.mean(e_pre))
e_post_f1 = float(np.mean(e_post))

fig, ax = plt.subplots(figsize=(9, 5))
x, width = np.array([0, 1]), 0.3
bars1 = ax.bar(x - width/2, [s_pre_f1, s_post_f1], width, color='#94A3B8',
               label='Static GCN', alpha=0.9)
bars2 = ax.bar(x + width/2, [e_pre_f1, e_post_f1], width, color='#0D9488',
               label='EvolveGCN-H', alpha=0.9)

for bar in list(bars1) + list(bars2):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
            f'{bar.get_height():.3f}', ha='center', va='bottom',
            fontsize=11, fontweight='bold')

ax.set_xticks(x)
ax.set_xticklabels(['Pre-T43\n(T37–T42)', 'Post-T43\n(T44–T49)'], fontsize=12)
ax.set_ylabel('Mean F1 Score (Illicit Class)', fontsize=11)
ax.set_title('Concept Drift Impact: Static GCN vs EvolveGCN-H\n'
             'Pre vs Post Dark Market Shutdown (T43)', fontsize=12, fontweight='bold')
ax.legend(fontsize=11)
ax.set_ylim(0, max(s_pre_f1, e_pre_f1) * 1.25 + 1e-6)
ax.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(FIGURES_DIR, 'pre_post_t43_comparison.png'), bbox_inches='tight')
plt.show()
print('Saved → figures/pre_post_t43_comparison.png')
# Out:
# Saved → figures/pre_post_t43_comparison.png

# %% [markdown]
# ---
# ## Cell 15 — Drift Probe

# %%
print('DRIFT PROBE — Train: T1–T16  |  Test: T33–T49  (warm-up from T1)')
print('=' * 60)

torch.manual_seed(SEED)
drift_model     = EvolveGCNH().to(device)
drift_model.reset_weights()
drift_optimizer = torch.optim.AdamW(drift_model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)

# Train on T1–T16 in chronological order
for epoch in range(MAX_EPOCHS):
    loss, _ = train_epoch(drift_model, drift_optimizer, DRIFT_TRAIN_IDX)
    if epoch % 50 == 0:
        print(f'  Epoch {epoch:>3}  Loss: {loss:.4f}')

# E4 — warm up through ALL snapshots from T1 (consistent with the main test),
# then report at T33–T49. Previously warm-up started at T33 with a fresh seed,
# so the near-random early AUROC was partly an artefact, not drift.
probe_results = evaluate_per_snapshot(drift_model, all_idx=ALL_IDX, eval_idx=DRIFT_TEST_IDX)

print()
print(f'{"T":>4}  {"F1":>8}  {"AUROC":>8}  Note')
print('-' * 40)
for r in probe_results:
    note      = '← SHUTDOWN' if r['time_step'] == SHUTDOWN_STEP else ''
    auroc_str = f"{r['AUROC']:.4f}" if not np.isnan(r['AUROC']) else 'nan   '
    print(f'T{r["time_step"]:>2}  {r["F1"]:>8.4f}  {auroc_str:>8}  {note}')

probe_pre  = [r['F1'] for r in probe_results if r['time_step'] < SHUTDOWN_STEP]
probe_post = [r['F1'] for r in probe_results if r['time_step'] > SHUTDOWN_STEP]
s_probe_pre  = static_summary['drift_probe']['mean_f1_pre_t43']
s_probe_post = static_summary['drift_probe']['mean_f1_post_t43']
print()
print(f'Mean F1 pre-T43  : {np.mean(probe_pre):.4f}   (Static GCN: {s_probe_pre})')
print(f'Mean F1 post-T43 : {np.mean(probe_post):.4f}   (Static GCN: {s_probe_post})')
print(f'Drop             : {np.mean(probe_pre) - np.mean(probe_post):.4f}')
# Out:
# DRIFT PROBE — Train: T1–T16  |  Test: T33–T49  (warm-up from T1)
# ...
#   Epoch   0  Loss: 0.8251
#   Epoch  50  Loss: 0.2632
#   Epoch 100  Loss: 0.1764
#   Epoch 150  Loss: 0.1374
#   Epoch 200  Loss: 0.1218
#   Epoch 250  Loss: 0.0983
#   Epoch 300  Loss: 0.1085
#   Epoch 350  Loss: 0.0799
#   Epoch 400  Loss: 0.0773
#   Epoch 450  Loss: 0.0749
#
#    T        F1     AUROC  Note
# ----------------------------------------
# T33    0.1606    0.7362
# T34    0.1340    0.5116
# T35    0.2855    0.6314
# T36    0.0531    0.6646
# T37    0.2338    0.7305
# T38    0.3611    0.6957
# T39    0.1616    0.6269
# T40    0.0611    0.4093
# T41    0.0407    0.3477
# T42    0.0495    0.3863
# T43    0.0000    0.4625  ← SHUTDOWN
# T44    0.0288    0.4867
# T45    0.0000    0.4503
# T46    0.0000    0.3585
# T47    0.0000    0.4632
# T48    0.0000    0.4165
# T49    0.0000    0.4583
#
# Mean F1 pre-T43  : 0.1541   (Static GCN: 0.284)
# Mean F1 post-T43 : 0.0048   (Static GCN: 0.0449)
# ...

# %% [markdown]
# ---
# ### Multi-seed robustness (E6 / G2)
#
# Re-train EvolveGCN-H under 5 seeds and report **mean ± std**. The seed-42 checkpoint
# above stays canonical for the SHAP notebook; this only quantifies variance and writes
# `evolvegcn_results_by_seed.json`. (5 × up to 500 epochs — expect this to run a while on T4.)

# %%
SEEDS = [42, 7, 13, 21, 100]

def run_single_seed_evolve(seed):
    torch.manual_seed(seed)
    np.random.seed(seed)
    mdl = EvolveGCNH().to(device)
    mdl.reset_weights()
    opt = torch.optim.AdamW(mdl.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
    sch = torch.optim.lr_scheduler.ReduceLROnPlateau(opt, mode='max', factor=0.5, patience=10) \
          if USE_SCHEDULER else None

    best_auroc, best_state, patience = 0.0, None, 0
    for epoch in range(MAX_EPOCHS):
        _, end_state = train_epoch(mdl, opt, TRAIN_IDX)
        va = evaluate_val(mdl, VAL_IDX, end_state)['AUROC']
        if sch is not None and not np.isnan(va):
            sch.step(va)
        if not np.isnan(va) and va > best_auroc:
            best_auroc = va
            best_state = {k: v.detach().cpu().clone() for k, v in mdl.state_dict().items()}
            patience = 0
        else:
            patience += 1
            if patience >= PATIENCE:
                break
    if best_state is not None:
        mdl.load_state_dict(best_state)

    test  = evaluate_test(mdl, ALL_IDX, TEST_IDX)
    psnap = evaluate_per_snapshot(mdl, ALL_IDX, TEST_IDX)
    pre   = [r['F1'] for r in psnap if 37 <= r['time_step'] < SHUTDOWN_STEP]
    post  = [r['F1'] for r in psnap if r['time_step'] > SHUTDOWN_STEP]
    return {
        'seed'             : seed,
        'best_val_auroc'   : round(float(best_auroc), 4),
        'test_F1'          : round(float(test['F1']), 4),
        'test_AUROC'       : round(float(test['AUROC']), 4),
        'test_Precision'   : round(float(test['Precision']), 4),
        'test_Recall'      : round(float(test['Recall']), 4),
        'pre_t43_mean_f1'  : round(float(np.mean(pre)), 4),
        'post_t43_mean_f1' : round(float(np.mean(post)), 4),
        'f1_drop'          : round(float(np.mean(pre) - np.mean(post)), 4),
    }

print('MULTI-SEED RUN — EvolveGCN-H')
print('=' * 70)
per_seed = []
for s in SEEDS:
    r = run_single_seed_evolve(s)
    per_seed.append(r)
    print(f"  seed {s:>3} | valAUROC {r['best_val_auroc']:.4f} | testF1 {r['test_F1']:.4f}"
          f" | pre {r['pre_t43_mean_f1']:.4f} | post {r['post_t43_mean_f1']:.4f}"
          f" | drop {r['f1_drop']:.4f}")

def _ms(key):
    vals = [r[key] for r in per_seed]
    return float(np.mean(vals)), float(np.std(vals))

print()
print(f'{"Metric":<18}{"mean ± std":>20}')
print('-' * 38)
seed_summary = {'seeds': SEEDS, 'per_seed': per_seed, 'mean_std': {}}
for key in ['test_F1', 'test_AUROC', 'test_Precision', 'test_Recall',
            'pre_t43_mean_f1', 'post_t43_mean_f1', 'f1_drop']:
    mu, sd = _ms(key)
    seed_summary['mean_std'][key] = {'mean': round(mu, 4), 'std': round(sd, 4)}
    print(f'{key:<18}{mu:>12.4f} ± {sd:.4f}')

seed_path = os.path.join(PROCESSED_DIR, 'evolvegcn_results_by_seed.json')
with open(seed_path, 'w') as f:
    json.dump(seed_summary, f, indent=2)
print(f'\nSaved → {seed_path}')
# Out:
# MULTI-SEED RUN — EvolveGCN-H
# ...
#   seed  42 | valAUROC 0.8869 | testF1 0.1986 | pre 0.1981 | post 0.0152 | drop 0.1830
#   seed   7 | valAUROC 0.8822 | testF1 0.3512 | pre 0.4049 | post 0.0833 | drop 0.3216
#   seed  13 | valAUROC 0.8853 | testF1 0.3065 | pre 0.3526 | post 0.0000 | drop 0.3526
#   seed  21 | valAUROC 0.8785 | testF1 0.1983 | pre 0.1919 | post 0.0000 | drop 0.1919
#   seed 100 | valAUROC 0.5000 | testF1 0.0000 | pre 0.0000 | post 0.0000 | drop 0.0000
#
# Metric                      mean ± std
# --------------------------------------
# test_F1                 0.2109 ± 0.1213
# test_AUROC              0.7483 ± 0.1246
# test_Precision          0.2268 ± 0.1164
# test_Recall             0.2051 ± 0.1351
# pre_t43_mean_f1         0.2295 ± 0.1421
# post_t43_mean_f1        0.0197 ± 0.0323
# f1_drop                 0.2098 ± 0.1249
#
# Saved → /content/drive/MyDrive/Capstone/Testing/data/processed/evolvegcn_results_by_seed.json

# %% [markdown]
# ---
# ## Cell 16 — Save All Outputs for Phase 4 SHAP

# %%
# E1 guard — never crash the summary save if the training cell was skipped
try:
    best_val_auroc
except NameError:
    best_val_auroc = float('nan')

model.eval()
all_outputs = {}
with torch.no_grad():
    for i in TEST_IDX:
        data = snapshots[i].to(device)
        out, emb = model(data.x, data.edge_index)
        probs    = torch.softmax(out, dim=1)[:, 1]
        all_outputs[i] = {
            'time_step'  : snapshots[i].time_step.item(),
            'preds'      : out.argmax(dim=1).cpu(),
            'probs'      : probs.cpu(),
            'embeddings' : emb.cpu(),
            'y_true'     : data.y.cpu(),
            'label_mask' : data.label_mask.cpu(),
        }

output_path = os.path.join(PROCESSED_DIR, 'evolvegcn_outputs.pt')
torch.save(all_outputs, output_path)
print(f'Outputs saved → {output_path}')

summary = {
    'model'            : 'EvolveGCN-H',
    'architecture'     : f'{IN_CHANNELS} → {HIDDEN1} → {HIDDEN2} → 2  (GRU-evolved, learnable W0)',
    'graph_standard'   : 'Weber (unknown nodes kept, label-masked loss)',
    'train_snapshots'  : 'T1–T34',
    'val_snapshots'    : 'T35–T36',
    'test_snapshots'   : 'T37–T49',
    'best_val_auroc'   : round(float(best_val_auroc), 4),
    'test_metrics'     : {k: round(v, 4) for k, v in evolve_metrics.items()},
    'per_snapshot'     : evolve_per_snap,
    'pre_t43_mean_f1'  : round(float(np.mean(e_pre)), 4),
    'post_t43_mean_f1' : round(float(np.mean(e_post)), 4),
    'f1_drop'          : round(float(np.mean(e_pre) - np.mean(e_post)), 4),
    'drift_probe'      : {
        'train'            : 'T1–T16',
        'test'             : 'T33–T49',
        'mean_f1_pre_t43'  : round(float(np.mean(probe_pre)), 4),
        'mean_f1_post_t43' : round(float(np.mean(probe_post)), 4),
    }
}

summary_path = os.path.join(PROCESSED_DIR, 'evolvegcn_summary.json')
with open(summary_path, 'w') as f:
    json.dump(summary, f, indent=2)
print(f'Summary saved  → {summary_path}')

print()
print('PHASE 3 COMPLETE')
print(f'  Static GCN  post-T43 F1 : {static_summary["post_t43_mean_f1"]}')
print(f'  EvolveGCN-H post-T43 F1 : {np.mean(e_post):.4f}')
print('  Next: run 04 SHAP for BOTH models (set MODEL_NAME) — compare W3→W4 τ.')
# Out:
# Outputs saved → /content/drive/MyDrive/Capstone/Testing/data/processed/evolvegcn_outputs.pt
# Summary saved  → /content/drive/MyDrive/Capstone/Testing/data/processed/evolvegcn_summary.json
#
# PHASE 3 COMPLETE
#   Static GCN  post-T43 F1 : 0.0264
#   EvolveGCN-H post-T43 F1 : 0.0152
#   Next: run 04 SHAP for BOTH models (set MODEL_NAME) — compare W3→W4 τ.
